# %% [markdown]
# ### Bài 1: Nhập vào 2 cạnh của một hình chữ nhật. In ra màn hình diệntíchvàchu vi của nó.

# %%
a = float(input())
b = float(input())
if a > 0 and b > 0:
    p = (a + b)*2
    s = a*b
print(p)
print(s)
# Out:
# 14.0
# 12.0

# %% [markdown]
# ### Bài 2: Nhập vào bán kính của hình tròn. In ra màn hình diện tích và chu vi của nó.

# %%
n = int(input())
if n > 0:
    pi = 3.14
    c = 2*pi*n
    s = pi*(n**2)
print(c)
print(s)
# Out:
# 18.84
# 28.26

# %% [markdown]
# ### Bài 3;  Tính tam giác: Nhâp vào ba số a,b,c bất kì. Kiểmtra xem nó có thể làđộ dài ba cạnh hay không, nếu không thì in ra màn hình 'Khong la ba canh cua mot tam giac'. Ngược lại, kiểm tra xem nó là tam giác gì: Đều, Cân, Vuông, hay Tam giác thường. Tính diện tích, chu vi của tam giác và in ra mànhình

# %%
import math

a = float(input())
b = float(input())
c = float(input())
if (a+b>c) and (a+c>b) and (b+c>a):
    if a == b == c :
        print("Tam giac deu")
    elif a == b or b == c or a == c :
        print("Tam giac can")
    elif (a**2 + b**2 == c**2) or (a**2 + c**2 == b**2) or (b**2 + c**2 == a**2):
        print("Tam giac vuong")
    else:
        print("tam giac thuong")
    if (a+b>c) and (a+c>b) and (b+c>a):
        chu_vi = a + b + c
        q = chu_vi/2
        s = math.sqrt(p/2*(p-a)*(p-b)*(p-c))
    print(chu_vi)
    print(s)
else:
    print("Khong phai la ba canh mot tam giac")
# Out:
# Tam giac vuong
# 12.0
# 54.99090833947008

# %% [markdown]
# ### Bài 4:  Viết chương trình giải phương trình bậc 1 (ax + b = 0)

# %%
a = float(input())
b = float(input())
if a != 0 :
    x = -b/a
    print(f"phuong trinh co nghiem duy nhat : x = {x}")
else:
    if b == 0 :
        print("phuong trinh co vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
# Out:
# phuong trinh co nghiem duy nhat : x = -1.25

# %% [markdown]
# ### Bài 5: Viết chương trình giải phương trình bậc 2 (ax2 + bx + c = 0)

# %%
import math

a = float(input())
b = float(input())
c = float(input())
if a == 0:
    if b == 0:
        if c == 0:
            print("phuong trinh co vo so nghiem")
        else:
            print("phuong trinh vo nghiem")
    else:
        print(f" phuong trinh co nghiem : x = {-c/b}")
else:
    delta = b**2 - 4*a*c
    if delta > 0 :
        x1 = (-b - math.sqrt(delta))/(2*a)
        x2 = (-b + math.sqrt(delta))/(2*a)
        print(f" phương trinh co hai nghiem phan biet : x = {x1, x2}")
    elif delta == 0:
        x = -b/a 
        print(f" phuong trinh co nghiem kep :x1 = x2 = {x}")
    else:
        print("phuong trinh vo nghiem")
# Out:
#  phương trinh co hai nghiem phan biet : x = (-2.0, -0.5)

# %% [markdown]
# ### Bài 6: Tìm giá trị lớn nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
a, b, c, d = map(int,input().split())
print(max (a,b,c,d))
# Out:
# 9

# %%
lst = list(map(int,input().split()))
if lst:
    print(max(lst))
# Out:
# 8

# %% [markdown]
# ### Bài 7: Tìm giá trị nhỏ nhất trong 4 số a, b, c, d (a, b, c, được nhập từ bànphím).

# %%
lst = list(map(int,input().split()))
if lst:
    print(min(lst))
# Out:
# 2

# %% [markdown]
# ### Bài 8: Giải hệ phương trình tuyến tính:
# #### ax + by = m
# #### cx + dy = n

# %%
a, b, c, d, m, n = map(float,input().split())
Det = a*d - b*c
Dx = b*n - m*d
Dy = a*n - m*c

if Det != 0:
    x = Dx/Det
    y = Dy/Det
    print(f"He co nghiem duy nhat : x = {x}, y = {y}")
else:
    if Dx == 0 and Dy == 0:
        print("He phuong trinh vo nghiem")
    else:
        print("He phuong trinh co vo so nghiem")
# Out:
# He co nghiem duy nhat : x = -7.75, y = -3.25

# %% [markdown]
# ### Bài 9: Nhập vào thời gian 1 công việc nào đó là x giây. Hãy chuyển đổi và viết ra màn hình số thời gian trên dưới dạng bằng bao nhiêu giờ, bao nhiêu phút, bao nhiêu giây

# %%
x = int(input())
y = phut
z = gio
if x > 0:
    y = x/60
    z = (x/60)/60
    print(x, y, z)
# Out:
# 7200 120.0 2.0

# %% [markdown]
# ### Bài 10: Nhập vào tâm và bán kính của một đường tròn. Sau đó nhập vàomộtđiểm A(x, y) bất kì và kiểm tra xem nó có thuộc đường tròn hay không?

# %%
import math

x0 = float(input())
y0 = float(input())
r = float(input())
x = float(input())
y = float(input())
d = math.sqrt((x - x0)**2 + (y - y0)**2)
if d == r:
    print("A nam tren duong tron")
else:
    print("A khong nam tren duong tron")
# Out:
# A khong nam tren duong tron

# %% [markdown]
# ### Bài 11: Tính x^y (Với x, y là số thực).

# %%
x = float(input())
y = float(input())
ket_qua = x**y
print(ket_qua)
# Out:
# 1679616.0
